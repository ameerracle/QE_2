# %%
from pathlib import Path
import sys
from ase.io import read
from ase.io import write
from ase.visualize import view
from ase.build import surface

# %%
combi = read('TiN_Li2S8_vasp.log')
view(combi)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 combi = read('TiN_Li2S8_vasp.log')
#       2 view(combi)
#
# File ~/miniforge3/envs/qe/lib/python3.13/site-packages/ase/io/formats.py:794, in read(filename, index, format, parallel, do_not_split_by_at_sign, **kwargs)
#     791     return list(_iread(filename, index, format, io, parallel=parallel,
#     792                        **kwargs))
#     793 else:
# --> 794     return next(_iread(filename, slice(index, None), format, io,
#     795                        parallel=parallel, **kwargs))
#
# StopIteration:
