# %%
from ase.io import read,write
from ase.visualize import view

metals = ['TiN','VN','ScN','ZrN','NbN']
for metal in metals:
    super = read(f"./primitive/{metal}_prim.poscar")
    #view(cif)
    mega = super.repeat((2, 2, 2))
    view(mega)
    write(f"./supercell/{metal}_supercell.cif", mega)

# %%
from ase.io import read,write
from ase.visualize import view
from readqe import read_qe_hubbard_out

cif = read_qe_hubbard_out("./atomic_cif/VN/vcrelax.out", index=-1)
view(cif)
# Out:
# <Popen: returncode: None args: ['/home/ameer_ubuntu/miniforge3/envs/qe/bin/p...>
