# %%
from ase.io import read, write
from ase.visualize import view
from ase.build import add_adsorbate
import pathlib
metals = ['ScN','TiN','ZrN','NbN','VN']
adsorbates = ['Li2S','Li2S2','Li2S4','Li2S6','Li2S8','S8']

# %%
metals = ['TiN', 'VN']
adsorbates = ['Li2S','Li2S2','Li2S4','Li2S6','Li2S8','S8']

adsorbate_path=pathlib.Path('/home/ameer_ubuntu/Git_projects/QE_2/adsorbates')
print(adsorbate_path)
slab_path=pathlib.Path('..')/'slab'/'output_files'
# Out:
# /home/ameer_ubuntu/Git_projects/QE_2/adsorbates

# %%
from ase.build import add_adsorbate
adsorbates = ['Li2S']
metals = ['TiN','VN']
from readqe import read_qe_hubbard_out
for metal in metals:
    slab = read_qe_hubbard_out(slab_path / f'{metal}_slab_relax' / f'{metal}_atomic.out')
    for adsorbate in adsorbates:
        ads = read(adsorbate_path / f'{adsorbate}/espresso.pwo')
        atom_78_pos = slab.get_positions()[78]  # Get atom 78 (x, y, z)
        x_y_coords = atom_78_pos[:2]  # Extract just x and y
        ads.rotate(45,'z')
        combi = slab.copy()
        add_adsorbate(combi, ads, 3, position=x_y_coords, mol_index=2)
        view(combi)
        
        save_path = pathlib.Path('.')/f'{metal}_{adsorbate}_combiU_144.xyz'
        write(save_path, combi)

# %%
from ase.build import add_adsorbate
from readqe import read_qe_hubbard_out
adsorbates = ['Li2S2']

for metal in metals:
    slab = read_qe_hubbard_out(slab_path / f'{metal}_slab_relax' / f'{metal}_atomic.out')
    for adsorbate in adsorbates:
        ads = read(adsorbate_path/f'{adsorbate}/espresso.pwo')
        atom_78_pos = slab.get_positions()[78]  # Get atom 78 (x, y, z)
        x_y_coords = atom_78_pos[:2]  # Extract just x and y
        ads.rotate(90,'y')
        ads.rotate(-45,'z')
        combi = slab.copy()
        add_adsorbate(combi, ads, 3, position=x_y_coords, mol_index=3)
        view(combi)
        save_path = pathlib.Path('.')/f'{metal}_{adsorbate}_combiU_144.xyz'
        write(save_path, combi)

# %%
from ase.build import add_adsorbate
from readqe import read_qe_hubbard_out
adsorbates = ['Li2S4']
for metal in metals:
    slab = read_qe_hubbard_out(slab_path / f'{metal}_slab_relax' / f'{metal}_atomic.out')
    for adsorbate in adsorbates:
        ads = read(adsorbate_path/f'{adsorbate}/espresso.pwo')
        atom_78_pos = slab.get_positions()[78]  # Get atom 78 (x, y, z)
        x_y_coords = atom_78_pos[:2]  # Extract just x and y
        #ads.rotate(90,'y')
        ads.rotate(45,'z')
        combi = slab.copy()
        add_adsorbate(combi, ads, 3, position=x_y_coords, mol_index=4)
        view(combi)
        save_path = pathlib.Path('.')/f'{metal}_{adsorbate}_combi_144.xyz'
        write(save_path, combi)

# %%
from ase.build import add_adsorbate
from readqe import read_qe_hubbard_out
adsorbates = ['Li2S6']
for metal in metals:
    slab = read_qe_hubbard_out(slab_path / f'{metal}_slab_relax' / f'{metal}_atomic.out')
    for adsorbate in adsorbates:
        ads = read(adsorbate_path/f'{adsorbate}/espresso.pwo')
        atom_78_pos = slab.get_positions()[78]  # Get atom 78 (x, y, z)
        x_y_coords = atom_78_pos[:2]  # Extract just x and y
        ads.rotate(180,'y')
        ads.rotate(45,'z')
        combi = slab.copy()
        add_adsorbate(combi, ads, 3, position=x_y_coords, mol_index=6)
        view(combi)
        save_path = pathlib.Path('.')/f'{metal}_{adsorbate}_combi_144.xyz'
        write(save_path, combi)

# %%
from ase.build import add_adsorbate
from readqe import read_qe_hubbard_out
adsorbates = ['Li2S8']
for metal in metals:
    slab = read_qe_hubbard_out(slab_path / f'{metal}_slab_relax' / f'{metal}_atomic.out')
    for adsorbate in adsorbates:
        ads = read(adsorbate_path/f'{adsorbate}/espresso.pwo')
        atom_78_pos = slab.get_positions()[78]  # Get atom 78 (x, y, z)
        x_y_coords = atom_78_pos[:2]  # Extract just x and y
        ads.rotate(200,'y')
        ads.rotate(-60,'x')
        ads.rotate(-195,'z')
        combi = slab.copy()
        add_adsorbate(combi, ads, 3, position=x_y_coords, mol_index=8)
        view(combi)
        save_path = pathlib.Path('.')/f'{metal}_{adsorbate}_combi_144.xyz'
        write(save_path, combi)

# %%
from ase.build import add_adsorbate
from readqe import read_qe_hubbard_out
adsorbates = ['S8']
for metal in metals:
    slab = read_qe_hubbard_out(slab_path / f'{metal}_slab_relax' / f'{metal}_atomic.out')
    for adsorbate in adsorbates:
        ads = read(adsorbate_path/f'{adsorbate}/espresso.pwo')
        atom_78_pos = slab.get_positions()[78]  # Get atom 78 (x, y, z)
        x_y_coords = atom_78_pos[:2]  # Extract just x and y
        ads.rotate(-195,'z')
        combi = slab.copy()
        add_adsorbate(combi, ads, 3.5, position=x_y_coords, mol_index=5)
        view(combi)
        save_path = pathlib.Path('.')/f'{metal}_{adsorbate}_combi_144.xyz'
        write(save_path, combi)

# %%
atoms = read('/home/ameer_ubuntu/Git_projects/QE_2/no_u/combi_144/TiN_Li2S8_combi_relax/TiN_Li2S8_combi_restart3.out',index=':')
view(atoms)
# Out:
# <Popen: returncode: None args: ['/home/ameer_ubuntu/miniforge3/envs/qe/bin/p...>
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/ameer_ubuntu/miniforge3/envs/qe/lib/python3.13/site-packages/ase/gui/pipe.py", line 34, in <module>
#     main()
#     ~~~~^^
#   File "/home/ameer_ubuntu/miniforge3/envs/qe/lib/python3.13/site-packages/ase/gui/pipe.py", line 30, in main
#     plt.show()
#     ~~~~~~~~^^
#   File "/home/ameer_ubuntu/miniforge3/envs/qe/lib/python3.13/site-packages/matplotlib/pyplot.py", line 613, in show
#     return _get_backend_mod().show(*args, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/ameer_ubuntu/miniforge3/envs/qe/lib/python3.13/site-packages/matplotlib_inline/backend_inline.py", line 90, in show
#     display(
#     ~~~~~~~^
#         figure_manager.canvas.figure,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
from ase.io import read, write
from ase.visualize import view
from ase.build import add_adsorbate
from readqe import read_qe_hubbard_out
import pathlib
combi = read_qe_hubbard_out('/home/ameer_ubuntu/Git_projects/QE_2/combi/VN_S8_combi_u.out',index=':')
view(combi)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 6
#       4 from readqe import read_qe_hubbard_out
#       5 import pathlib
# ----> 6 combi = read_qe_hubbard_out('/home/ameer_ubuntu/Git_projects/QE_2/combi/VN_S8_combi_u.out',index=':')
#       7 view(combi)
#
# File ~/Git_projects/QE_2/readqe.py:358, in read_qe_hubbard_out(filename, index)
#     357 def read_qe_hubbard_out(filename: Union[str, Path], index: IndexLike = -1) -> Union[Atoms, List[Atoms]]:
# --> 358     snapshots = _parse_qe_out_all(filename)
#     359     if not snapshots:
#     360         raise ValueError(f"No geometry snapshots found in {filename}")
#
# File ~/Git_projects/QE_2/readqe.py:228, in _parse_qe_out_all(filename)
#     226 def _parse_qe_out_all(filename: Union[str, Path]) -> List[Atoms]:
#     227     path = Path(filename)
# ...
