# %%
import argparse
import os
import subprocess
from pathlib import Path
from ase.visualize import view
from readqe import read_qe_hubbard_out
from ase.io import read

# %%
metals =['TiN','VN']
adsorbate = ['Li2S8']
for metal in metals:
    for ads in adsorbate:
        combi = read_qe_hubbard_out(f'{metal}_{ads}_combi_relax_u/{metal}_{ads}_combi_u.out',index=':')
        view(combi)
